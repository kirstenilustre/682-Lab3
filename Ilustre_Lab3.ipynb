# %% [markdown]
# ## Kirsten Ilustre
# ## April 13, 2020
# **GEOG 682 Lab 3**

# %%
import rasterio
from rasterio import plot
import matplotlib.pyplot as plt

# %%
sent1 = rasterio.open("image1.tif")

# %%
sent2 = rasterio.open("image2.tif")

# %%
plot.show(sent1, cmap='terrain')

# %%
plot.show(sent2, cmap='terrain')

# %%
sent1.crs
# Out:
# CRS.from_epsg(32618)

# %%
sent2.crs
# Out:
# CRS.from_epsg(32618)

# %% [markdown]
# WGS 84 / UTM zone 18 N

# %%
fig, (axr, axg, axb) = plt.subplots(1,3, figsize=(20,5))
plot.show((sent1, 3), ax=axr, cmap='Reds', title='red channel')
plot.show((sent1, 2), ax=axg, cmap='Greens', title='green channel')
plot.show((sent1, 1), ax=axb, cmap='Blues', title='blue channel')

# %%
from rasterio.merge import merge
from rasterio.plot import show
import numpy as np

# %%
sent_to_mosaic = [sent1, sent2]

# %%
mosaic, out_trans = merge (sent_to_mosaic)

# %%
show(mosaic, cmap='terrain')
